# %% [markdown]
# ## Script for generating plots related to the report

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow_datasets as tfds
import tensorflow as tf
import pandas as pd
import tensorflow_text
# Out:
# 2024-10-06 23:28:25.141099: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-06 23:28:25.309489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-06 23:28:25.368152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-06 23:28:25.383527: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
def getFileName(file_path, title = False):
        # Extracting the file name without the extension
    file_name = os.path.splitext(os.path.basename(file_path))[0]

    # Formatting the title (replace underscores with spaces and capitalize)
    formatted_title = file_name
    if title:
        formatted_title = file_name.title

    return formatted_title

# %%
def saveAsSvg(filename):
    # Save the plot as a PDF for LaTeX embedding
    output_pdf = f'/work3/s174159/LLM_Thesis/plots/img_pdf/{filename}.pdf'
    plt.savefig(output_pdf)
    print("Saved image")

# %% [markdown]
# ## Experimental setup

# %%
# Load your CSV data
file_path = "/work3/s174159/LLM_Thesis/plots/data/constraint_v_noConstraint_macroF1.csv"
data = pd.read_csv(file_path)

# %%
# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Plotting the two configurations with both markers and lines
plt.plot(data['1_Combined_RE_NoConstraint_0.1_30_5e-05_1_0.1 - macro_F1'].dropna(), 
        label='No Constraint - Macro F1', linestyle='-', markersize=6)
plt.plot(data['1_Combined_RE_Constraint_0.1_30_5e-05_1_0.1 - macro_F1'].dropna(), 
        label='Constraint - Macro F1', linestyle='-', markersize=6)


# Adding titles and labels
plt.title('Comparison of Macro F1 between Constraint and No Constraint Models')
plt.xlabel('Steps')
plt.ylabel('F1 Score %')
plt.grid(True)

# Add a legend to distinguish the lines
plt.legend()

saveAsSvg(getFileName(file_path))

# Display the plot
plt.show()
# Out:
# Saved image

# %%
# Load your CSV data
file_path = '/work3/s174159/LLM_Thesis/plots/data/constraint_v_noConstraint.csv'
data = pd.read_csv(file_path)

# %%
# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Plotting the two configurations with both markers and lines
plt.plot(data['1_Combined_RE_NoConstraint_0.1_30_5e-05_1_0.1 - dev_F1'].dropna(), 
        label='No Constraint - Micro F1', linestyle='-', markersize=6)
plt.plot(data['1_Combined_RE_Constraint_0.1_30_5e-05_1_0.1 - dev_F1'].dropna(), 
        label='Constraint - Micro F1', linestyle='-', markersize=6)


# Adding titles and labels
plt.title('Comparison of Micro F1 between Constraint and No Constraint Models')
plt.xlabel('Steps')
plt.ylabel('F1 Score %')
plt.grid(True)

# Add a legend to distinguish the lines
plt.legend()

saveAsSvg(getFileName(file_path))

# Display the plot
plt.show()
# Out:
# Saved image

# %%
# Load your CSV data
file_path = '/work3/s174159/LLM_Thesis/plots/data/F1MACRO_REBEL.csv'
data = pd.read_csv(file_path)
data
# Out:
#     Step  Default - ReDocRED - BASELINE - No Constraints - macro_f1  \
# 0      0                                           0.000000
# 1     50                                           0.000000
# 2    150                                           6.866343
# 3    250                                          12.564769
# 4    350                                          18.178776
# 5    449                                          22.400243
# 6    549                                          24.097441
# 7    649                                          26.336283
# 8    749                                          27.808291
# 9    849                                          17.450314
# 10   949                                          15.188404
# 11  1049                                          25.918911
# 12  1149                                          29.367312
# 13  1200                                          32.183814
# ...

# %%
# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Plotting the two configurations with both markers and lines
plt.plot(data['Default - ReDocRED - BASELINE - No Constraints - macro_f1'].dropna(), 
        label='Default', linestyle='-', markersize=6)
plt.plot(data['REBEL - ReDocRED - BASELINE - No Constraints - macro_f1'].dropna(), 
        label='REBEL', linestyle='-', markersize=6)


# Adding titles and labels
plt.title('Macro F1 comparison between default (BART) and REBEL')
plt.xlabel('Steps')
plt.ylabel('Macro F1 Score %')
plt.grid(True)

# Add a legend to distinguish the lines
plt.legend()

saveAsSvg(getFileName(file_path))

# Display the plot
plt.show()
# Out:
# Saved image

# %%
# Load your CSV data
file_path = '/work3/s174159/LLM_Thesis/plots/data/F1MICRO_REBEL.csv'
data = pd.read_csv(file_path)
data
# Out:
#     Step  Default - ReDocRED - BASELINE - No Constraints - val_F1_micro  \
# 0     95                                           0.000000
# 1    191                                          15.936999
# 2    287                                          21.448213
# 3    383                                          28.101959
# 4    479                                          34.188034
# 5    575                                          36.973377
# 6    671                                          38.248121
# 7    767                                          40.240741
# 8    863                                          33.183251
# 9    959                                          30.897250
# 10  1055                                          40.851396
# 11  1151                                          43.713032
# 12  1247                                          44.780635
# 13  1343                                          41.902419
# ...

# %%
# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Set figure size for better visualization
plt.figure(figsize=(10, 6))

# Plotting the two configurations with both markers and lines
plt.plot(data['Default - ReDocRED - BASELINE - No Constraints - val_F1_micro'].dropna(), 
        label='Default', linestyle='-', markersize=6)
plt.plot(data['REBEL - ReDocRED - BASELINE - No Constraints - val_F1_micro'].dropna(), 
        label='REBEL', linestyle='-', markersize=6)


# Adding titles and labels
plt.title('Micro F1 comparison between default (BART) and REBEL')
plt.xlabel('Steps')
plt.ylabel('Macro F1 Score %')
plt.grid(True)

# Add a legend to distinguish the lines
plt.legend()

saveAsSvg(getFileName(file_path))

# Display the plot
plt.show()
# Out:
# Saved image

# %% [markdown]
# ## Positional encoding
# source: https://www.tensorflow.org/text/tutorials/transformer?hl=en

# %%
def positional_encoding(length, depth):
  depth = depth/2

  positions = np.arange(length)[:, np.newaxis]     # (seq, 1)
  depths = np.arange(depth)[np.newaxis, :]/depth   # (1, depth)

  angle_rates = 1 / (10000**depths)         # (1, depth)
  angle_rads = positions * angle_rates      # (pos, depth)

  pos_encoding = np.concatenate(
      [np.sin(angle_rads), np.cos(angle_rads)],
      axis=-1) 

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
pos_encoding = positional_encoding(length=2048, depth=512).numpy().T

# %%
# Check the shape.
print(pos_encoding.shape)

# Plot the dimensions.
plt.pcolormesh(pos_encoding, cmap='RdBu', rasterized=True)
plt.ylabel('Depth')
plt.xlabel('Position')
plt.colorbar()
plt.savefig("./img_pdf/positional_encoding.pdf",dpi=500)
plt.show()
# Out:
# (512, 2048)
