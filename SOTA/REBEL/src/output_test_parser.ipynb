# %%
output = """[
    {'predictions': [
            [
                {'head': 'Hakawati Theatre', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Arab east Jerusalem', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'PERUGIA', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Italy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Reagan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'America', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Reagan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Washington', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'University of Virginia', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Charlottesville', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wright', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Texas', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Nikita Khrushchev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Anastas Mikoyan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Hakawati Theatre', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Jerusalem', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'PERUGIA', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Italy', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'PERUGIA', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Italy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Reagan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'America', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Washington', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'University of Virginia', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Charlottesville', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wright', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Texas', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Nikita Khrushchev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Anastas Mikoyan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                },
                {'head': 'Khrushchev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Mikoyan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Alekseev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'MILAN', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Italy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Hot Springs National Park', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ark.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Aguadilla', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Puerto Rico', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Fort Wainwright annex', 'head_type': 'Location', 'type': 'Alaska', 'tail': 'Fairbanks', 'tail_type': 'Location'
                },
                {'head': 'Fort Wainwright annex', 'head_type': 'Location', 'type': 'Alaska', 'tail': 'Located In', 'tail_type': 'Location'
                },
                {'head': 'Fort Wainwright annex', 'head_type': 'Location', 'type': 'Alaska', 'tail': 'Located In', 'tail_type': 'Location'
                },
                {'head': 'Fairbanks', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Alaska', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ATLANTIC CITY', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.J.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'FRESNO', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Calif.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Mikoyan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                },
                {'head': 'Khrushchev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Alekseev', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'MILAN', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Italy', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'MILAN', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Italy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Hot Springs National Park', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ark.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Aguadilla', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Puerto Rico', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Fort Wainwright annex', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Fairbanks', 'tail_type': 'Location'
                },
                {'head': 'Fort Wainwright annex', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Alaska', 'tail_type': 'Location'
                },
                {'head': 'Fairbanks', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Alaska', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ATLANTIC CITY', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.J.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'FRESNO', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Calif.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Yerevan', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Armenia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Michael D. Papagiannis', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Boston University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ostined', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Czechoslovakia', 'tail_type': 'Location'
                },
                {'head': 'Ostined', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Austria', 'tail_type': 'Location'
                },
                {'head': 'Gmund', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Austria', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'BONE', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': "Bingham County Sheriff's Lt. Bill Gordon", 'head_type': 'Person', 'type': 'Live in', 'tail': 'Bingham County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Yves Fortier', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Canada', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bert Shanas', 'head_type': 'Person', 'type': 'Work for', 'tail': 'United Federation of Teachers', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Michael Coats', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Navy', 'tail_type': 'Organization'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Bolshoi Ballet', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                },
                {'head': 'Bolshoi Ballet', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                },
                {'head': 'Kirov Ballet', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Leningrad', 'tail_type': 'Location'
                },
                {'head': 'June Anderson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Carol Vaness', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Michael D. Papagiannis', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Boston University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ostined', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Czechoslovakia', 'tail_type': 'Location'
                },
                {'head': 'Lesny', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Czechoslovakia', 'tail_type': 'Location'
                },
                {'head': 'Liberec', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Czechoslovakia', 'tail_type': 'Location'
                },
                {'head': 'Gmund', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Austria', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'BONE', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bill Gordon', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Bingham County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Yves Fortier', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Canada', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bert Shanas', 'head_type': 'Person', 'type': 'Work for', 'tail': 'United Federation of Teachers', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Michael Coats', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Navy', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Ontario', 'head_type': 'Location', 'type': 'Located In', 'tail': 'California', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'McAllen', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Steve Wright', 'head_type': 'Person', 'type': 'Work for', 'tail': 'DOE', 'tail_type': 'Organization'
                },
                {'head': 'Steve Wright', 'head_type': 'Person', 'type': 'Work for', 'tail': 'SRP', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bert Byers', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Cecil Field Naval Air Station', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Poitiers', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Judith C. Toth', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Maryland', 'tail_type': 'Location'
                },
                {'head': 'Judith C. Toth', 'head_type': 'Person', 'type': 'Work for', 'tail': 'House of Delegates', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Center for Disease Control', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Fort Collins', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Shoshone-Bannock', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Ontario', 'head_type': 'Location', 'type': 'Located In', 'tail': 'California', 'tail_type': 'Location'
                },
                {'head': 'El Toro', 'head_type': 'Location', 'type': 'Located In', 'tail': 'California', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Yellowstone', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Wyo.', 'tail_type': 'Location'
                },
                {'head': 'McAllen', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Steve Wright', 'head_type': 'Person', 'type': 'Work for', 'tail': 'DOE', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bert Byers', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Cecil Field Naval Air Station', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bayonee', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Bayonee', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Bonloc', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Bonloc', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Poitiers', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Poitiers', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'House of Delegates', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Maryland', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Center for Disease Control', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Fort Collins', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Shoshone-Bannock reservation', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Albert O. Harjula', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Thomaston', 'tail_type': 'Location'
                },
                {'head': 'Albert O. Harjula', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Department of Inland Fisheries and Wildlife', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Idaho Falls', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Nixon', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ralph K. Winter', 'head_type': 'Person', 'type': 'Work for', 'tail': '2nd U.S. Circuit Court of Appeals', 'tail_type': 'Organization'
                },
                {'head': '2nd U.S. Circuit Court of Appeals', 'head_type': 'Organization', 'type': 'Work for', 'tail': 'New York', 'tail_type': 'Location'
                },
                {'head': 'Kenneth Starr', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.S. Circuit Court of Appeals', 'tail_type': 'Organization'
                },
                {'head': 'Kenneth Starr', 'head_type': 'Person', 'type': 'Live in', 'tail': 'District of Columbia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Omaha Beach', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Normandy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Darryl Breniser', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Blue Ball', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Terry Hands', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Stratford-upon-Avon', 'tail_type': 'Location'
                },
                {'head': 'Terry Hands', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Barbican', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'NASHVILLE', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tenn.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Albert O. Harjula', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Thomaston', 'tail_type': 'Location'
                },
                {'head': 'Paul Fournier', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Department of Inland Fisheries and Wildlife', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Idaho Falls', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bush', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ralph K. Winter', 'head_type': 'Person', 'type': 'Work for', 'tail': '2nd U.S. Circuit Court of Appeals', 'tail_type': 'Organization'
                },
                {'head': '2nd U.S. Circuit Court of Appeals', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'New York', 'tail_type': 'Location'
                },
                {'head': 'Kenneth Starr', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.S. Circuit Court of Appeals', 'tail_type': 'Organization'
                },
                {'head': 'U.S. Circuit Court of Appeals', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'District of Columbia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Omaha Beach', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Normandy', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Darryl Breniser', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Blue Ball', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Barbican', 'head_type': 'Location', 'type': 'Located In', 'tail': 'London', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'NASHVILLE', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tenn.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'TUNIS', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tunisia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Navy', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Chedli Klibi', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Arab League', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Abrams', 'head_type': 'Person', 'type': 'Work for', 'tail': 'LCB', 'tail_type': 'Organization'
                },
                {'head': 'Abrams', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Bush', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Memphis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tenn.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eduard A. Shevardnadze', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Li', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Beijing', 'tail_type': 'Location'
                },
                {'head': 'Li', 'head_type': 'Person', 'type': 'Live in', 'tail': 'China', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Khmer Rouge', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Cambodia', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'TUNIS', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tunisia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Navy', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Navy', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Chedli Klibi', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Arab League', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Abrams', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Latin America bureau', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Memphis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tenn.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eduard A. Shevardnadze', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Soviet', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Li', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Beijing', 'tail_type': 'Location'
                },
                {'head': 'Li', 'head_type': 'Person', 'type': 'Live in', 'tail': 'China', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Khmer Rouge', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Cambodia', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Walesa', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Solidarity', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bradley First Air', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Ottawa', 'tail_type': 'Location'
                },
                {'head': 'Bradley First Air', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Canada', 'tail_type': 'Location'
                },
                {'head': 'Ottawa', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Canada', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eastport International', 'head_type': 'Organization', 'type': 'Md.', 'tail': 'Upper Marlboro', 'tail_type': 'Location'
                },
                {'head': 'Eastport International', 'head_type': 'Location', 'type': 'Md.', 'tail': 'Organization based in', 'tail_type': 'Organization'
                },
                {'head': 'Eastport International', 'head_type': 'Location', 'type': 'Md.', 'tail': 'Organization based in', 'tail_type': 'Organization'
                },
                {'head': 'Upper Marlboro', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Md.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sultan Al-Saud', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Saudi Arabia', 'tail_type': 'Location'
                },
                {'head': 'Rodolfo Neri Vela', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Mexico', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Livingston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Montana', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Folke Nyberg', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Washington', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Puget Sound', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Seattle', 'tail_type': 'Location'
                },
                {'head': 'Puget Sound', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Washington', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William J. Bennett', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Walesa', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Solidarity', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bradley First Air', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Ottawa', 'tail_type': 'Location'
                },
                {'head': 'Bradley First Air', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Canada', 'tail_type': 'Location'
                },
                {'head': 'Ottawa', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Canada', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eastport International', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Upper Marlboro, Md.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sultan Al-Saud', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Saudi Arabia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rocky Mountains', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Montana', 'tail_type': 'Location'
                },
                {'head': 'Livingston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Rocky Mountains', 'tail_type': 'Location'
                },
                {'head': 'Livingston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Montana', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Folke Nyberg', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Washington', 'tail_type': 'Organization'
                },
                {'head': 'Seattle', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Pacific Rim', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Puget Sound', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Seattle', 'tail_type': 'Location'
                },
                {'head': 'Lake Washington', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Seattle', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William J. Bennett', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Samuel L. Husk', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Council of Great City Schools', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Nettie Johnson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Navy', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'G. Ernest Tidwell', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Francisco Rojas', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pemex', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ricardo Camero Cardiel', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Ciudad Madero', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Aussedat-Rey SA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Europe', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ann Silvernail', 'head_type': 'Person', 'type': 'Work for', 'tail': 'International Paper', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'GIESSEN', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West Germany', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Samuel L. Husk', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Council of Great City Schools', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Nettie Johnson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Navy', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'G. Ernest Tidwell', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Francisco Rojas', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pemex', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ricardo Camero Cardiel', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Ciudad Madero', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Aussedat-Rey SA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Europe', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ann Silvernail', 'head_type': 'Person', 'type': 'Work for', 'tail': 'International Paper', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'GIESSEN', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West Germany', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'GIESSEN', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'West Germany', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Rollei', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Braunschweig', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Hans Guenther von Zydowitz', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Leica', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Scott Hinton', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Elders Futures Inc.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'James K. Batten', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Knight-Ridder', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Eaglebrook East', 'head_type': 'Organization', 'type': 'Chicago', 'tail': 'Middletown', 'tail_type': 'Location'
                },
                {'head': 'Eaglebrook East', 'head_type': 'Location', 'type': 'Eaglebrook Plastics Inc.', 'tail': 'Located In', 'tail_type': 'Location'
                },
                {'head': 'Eaglebrook East', 'head_type': 'Organization', 'type': 'Chicago', 'tail': 'Organization based in', 'tail_type': 'Organization'
                },
                {'head': 'Eaglebrook East', 'head_type': 'Location', 'type': 'Chicago', 'tail': 'Organization based in', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'BEIRUT', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Lebanon', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William R. Higgins', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.S. Marine Corps', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Higgins', 'head_type': 'Person', 'type': 'Kill', 'tail': 'American spy Higgins', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Leica company', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Wetzlar', 'tail_type': 'Location'
                },
                {'head': 'Rollei', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Braunschweig', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Hans Guenther von Zydowitz', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Leica', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Scott Hinton', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Elders Futures Inc.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'James K. Batten', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Knight-Ridder', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Eaglebrook Plastics Inc.', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Chicago', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'BEIRUT', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Lebanon', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'BEIRUT', 'tail_type': 'Location'
                },
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Lebanon', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William R. Higgins', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Higgins', 'head_type': 'Person', 'type': 'Live in', 'tail': 'America', 'tail_type': 'Location'
                },
                {'head': 'Higgins', 'head_type': 'Person', 'type': 'Live in', 'tail': 'America', 'tail_type': 'Location'
                },
                {'head': 'Higgins', 'head_type': 'Person', 'type': 'Live in', 'tail': 'America', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'John Jamison', 'head_type': 'Person', 'type': 'Galveston.', 'tail': 'National Weather Service', 'tail_type': 'Organization'
                },
                {'head': 'John Jamison', 'head_type': 'Location', 'type': 'Galveston.', 'tail': 'Work for', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Greenland Expedition Society', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Greenland', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Vaughan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Army Air Force', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Cadiz', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kentucky.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'NEW ORLEANS', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Pacific Marine Inc.', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Houston', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sandi Sacher', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Boise', 'tail_type': 'Location'
                },
                {'head': 'Sandi Sacher', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho.', 'tail_type': 'Location'
                },
                {'head': 'Sandi Sacher', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Boise', 'tail_type': 'Location'
                },
                {'head': 'Sandi Sacher', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho.', 'tail_type': 'Location'
                },
                {'head': 'Boise', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sacher', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'John Jamison', 'head_type': 'Person', 'type': 'Work for', 'tail': 'National Weather Service', 'tail_type': 'Organization'
                },
                {'head': 'National Weather Service', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Galveston.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Pat Epps', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Greenland Expedition Society', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Vaughan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Air Force', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Mrs. Say', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Kentucky.', 'tail_type': 'Location'
                },
                {'head': 'Cadiz', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kentucky.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'AP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'NEW ORLEANS', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Pacific Marine Inc.', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Houston', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Boise', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'West', 'head_type': 'Location', 'type': 'Located In', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Alaska', 'head_type': 'Location', 'type': 'Located In', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Tom Van Sant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Santa Monica', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Gerald Baliles', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Virginia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Baliles', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Virginia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bush', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mombasa', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kenya', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Shaw Yu-ming', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Government Information', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'National Press Building', 'head_type': 'Location', 'type': 'U.S.', 'tail': 'Washington', 'tail_type': 'Location'
                },
                {'head': 'National Press Building', 'head_type': 'Location', 'type': 'U.S.', 'tail': 'Located In', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wyeth-Ayerst Laboratories', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Philadelphia.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Tom Van Sant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Santa Monica', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Gerald Baliles', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Virginia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Baliles', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Virginia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bush', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'European Community', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Europe.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mombasa', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kenya', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Shaw Yu-ming', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Government Information', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'National Press Building', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Washington', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wyeth-Ayerst Laboratories', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Philadelphia.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Cape Hatteras', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.C.', 'tail_type': 'Location'
                },
                {'head': 'Cape Hatteras', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.C.', 'tail_type': 'Location'
                },
                {'head': 'Jacksonville', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.C.', 'tail_type': 'Location'
                },
                {'head': 'Dodge City', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Klamath Falls', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ore.', 'tail_type': 'Location'
                },
                {'head': 'Klamath Falls', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ariz.', 'tail_type': 'Location'
                },
                {'head': 'Yuma', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ariz.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Fort Lewis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Wash.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Payette National Forest', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'La Grande', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Oregon', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mike Ferris.', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Forest Service', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'John Stembridge.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Miami', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Robert Bernero', 'head_type': 'Person', 'type': 'Work for', 'tail': 'NRC', 'tail_type': 'Organization'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Cape Hatteras', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.C.', 'tail_type': 'Location'
                },
                {'head': 'Jacksonville', 'head_type': 'Location', 'type': 'Located In', 'tail': 'N.C.', 'tail_type': 'Location'
                },
                {'head': 'Dodge City', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Kan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Klamath Falls', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ore.', 'tail_type': 'Location'
                },
                {'head': 'Yuma', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ariz.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Fort Lewis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Wash.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Dave Olson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho', 'tail_type': 'Location'
                },
                {'head': 'Payette National Forest', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'La Grande', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Oregon', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mike Ferris.', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Forest Service', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'John Stembridge.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Miami', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Robert Bernero', 'head_type': 'Person', 'type': 'Work for', 'tail': 'NRC', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Khieu Samphan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Khmer Rouge', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Grand Isle', 'head_type': 'Location', 'type': 'Located In', 'tail': 'La.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Malcolm Grant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Port Arthur.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lake Charles', 'head_type': 'Location', 'type': 'Located In', 'tail': 'La.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Warwick', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Rhode Island', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jack Frazier', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Rotary Club', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Tom Defelice', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Warwick', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sherman Finesilver', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Sherman Finesilver', 'head_type': 'Person', 'type': 'Work for', 'tail': 'John C. Keene', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Khieu Samphan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Khmer Rouge', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Grand Isle', 'head_type': 'Location', 'type': 'Located In', 'tail': 'La.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Malcolm Grant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Port Arthur', 'tail_type': 'Location'
                },
                {'head': 'Malcolm Grant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Port Arthur.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lutie Dyson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lake Charles', 'tail_type': 'Location'
                },
                {'head': 'Lutie Dyson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'La.', 'tail_type': 'Location'
                },
                {'head': 'Lake Charles', 'head_type': 'Location', 'type': 'Located In', 'tail': 'La.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Warwick', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Rhode Island', 'tail_type': 'Location'
                },
                {'head': 'Pawtuxet River.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Rhode Island', 'tail_type': 'Location'
                },
                {'head': 'Pawtuxet River.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Warwick', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jack Frazier', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Rotary Club', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Tom Defelice', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Warwick', 'tail_type': 'Location'
                },
                {'head': 'Disney World', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Florida', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Sherman Finesilver', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Booth Gardner', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Washington', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Cecil Andrus', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Javier Perez de Cuellar.', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.N.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'John Johnson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'New England Telephone', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bernice McIntyre', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Public Utilities Commission.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Anchorage', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Alaska', 'tail_type': 'Location'
                },
                {'head': 'Anchorage', 'head_type': 'Location', 'type': 'Located In', 'tail': 'South Korea.', 'tail_type': 'Location'
                },
                {'head': 'Seoul', 'head_type': 'Location', 'type': 'Located In', 'tail': 'South Korea.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Louis Sullivan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'HHS', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Joseph R. Biden', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Senate Judiciary Committee', 'tail_type': 'Organization'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Terry Branstad', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Iowa', 'tail_type': 'Location'
                },
                {'head': 'Terry Branstad', 'head_type': 'Person', 'type': 'Work for', 'tail': "National Governors'Association", 'tail_type': 'Organization'
                },
                {'head': 'Booth Gardner', 'head_type': 'Person', 'type': 'Work for', 'tail': "National Governors'Association", 'tail_type': 'Organization'
                },
                {'head': 'Booth Gardner', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Washington', 'tail_type': 'Location'
                },
                {'head': 'Branstad', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Iowa', 'tail_type': 'Location'
                },
                {'head': 'Branstad', 'head_type': 'Person', 'type': 'Work for', 'tail': "National Governors'Association", 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Cecil Andrus', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Javier Perez de Cuellar.', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.N.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'John Johnson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'XBT Telecom', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Bernice McIntyre', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Public Utilities Commission.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Anchorage', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Alaska', 'tail_type': 'Location'
                },
                {'head': 'Seoul', 'head_type': 'Location', 'type': 'Located In', 'tail': 'South Korea.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Louis Sullivan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'HHS', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Joseph R. Biden', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Senate Judiciary Committee', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Pentagon', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Revolutionary Justice Organization', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beirut', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Anderson', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Beirut', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jacobsen', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Colorado', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wyatt McCauley', 'head_type': 'Person', 'type': 'Work for', 'tail': 'CH2M Hill', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ellington Air Force Base', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas.', 'tail_type': 'Location'
                },
                {'head': 'Galveston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William P. Albrecht', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Commodity Futures Trading Commission.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Charing Cross Hospital', 'head_type': 'Location', 'type': 'Located In', 'tail': 'London', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Pentagon', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'An-Nahar.', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beirut', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Anderson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Middle East', 'tail_type': 'Location'
                },
                {'head': 'Anderson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'The Associated Press', 'tail_type': 'Organization'
                },
                {'head': 'The Associated Press', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Middle East', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jacobsen', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Colorado', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wyatt McCauley', 'head_type': 'Person', 'type': 'Work for', 'tail': 'CH2M Hill', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Houston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas.', 'tail_type': 'Location'
                },
                {'head': 'Ellington Air Force Base', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas.', 'tail_type': 'Location'
                },
                {'head': 'Galveston', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Texas.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'William P. Albrecht', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Commodity Futures Trading Commission.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Ogdon', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Manygate Management', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Vaughn Van Zant.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'King County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Peter Murtha', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Justice Department', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Kim Dae-jung', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Korea', 'tail_type': 'Location'
                },
                {'head': 'Kim Dae-jung', 'head_type': 'Person', 'type': 'Work for', 'tail': 'opposition party', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Greg Thayer', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.S. Forest Service.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Sierra Nevada foothills', 'head_type': 'Location', 'type': 'Located In', 'tail': 'California', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Joseph S. Murphy', 'head_type': 'Person', 'type': 'Work for', 'tail': 'City University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Boise Interagency Fire Center', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'West', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Cecil Andrus', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Debra Sweiger', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Issaquah', 'tail_type': 'Location'
                },
                {'head': 'Debra Sweiger', 'head_type': 'Person', 'type': 'Live in', 'tail': 'King County', 'tail_type': 'Location'
                },
                {'head': 'Issaquah', 'head_type': 'Location', 'type': 'Located In', 'tail': 'King County', 'tail_type': 'Location'
                },
                {'head': 'Vaughn Van Zant.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'King County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mike Norton', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Ken Fimberg', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Denver', 'tail_type': 'Location'
                },
                {'head': 'Peter Murtha', 'head_type': 'Person', 'type': 'Live in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Peter Murtha', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Justice Department', 'tail_type': 'Organization'
                },
                {'head': 'Peter Murtha', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Washington.', 'tail_type': 'Location'
                },
                {'head': 'Justice Department', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Justice Department', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Washington.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Dae-jung', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Korea', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Cascade', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Washington', 'tail_type': 'Location'
                },
                {'head': 'Greg Thayer', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U.S. Forest Service.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Sierra Nevada', 'head_type': 'Location', 'type': 'Located In', 'tail': 'California', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Joseph S. Murphy', 'head_type': 'Person', 'type': 'Work for', 'tail': 'City University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Idaho', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West', 'tail_type': 'Location'
                },
                {'head': 'Oregon', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West', 'tail_type': 'Location'
                },
                {'head': 'California', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West', 'tail_type': 'Location'
                },
                {'head': 'Washington', 'head_type': 'Location', 'type': 'Located In', 'tail': 'West', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Cecil Andrus', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Idaho', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Jeff Widener', 'head_type': 'Person', 'type': 'Work for', 'tail': 'AP', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Klong Toey', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Bangkok', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bernard Vandermeersch', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Bordeaux', 'tail_type': 'Organization'
                },
                {'head': 'Bernard Vandermeersch', 'head_type': 'Person', 'type': 'Live in', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Bernard Vandermeersch', 'head_type': 'Person', 'type': 'Live in', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'Bordeaux', 'head_type': 'Location', 'type': 'Located In', 'tail': 'France', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Carlos Tenev', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Peronist Party', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Guernsey', 'head_type': 'Location', 'type': 'Channel Islands', 'tail': 'Britain', 'tail_type': 'Location'
                },
                {'head': 'Guernsey', 'head_type': 'Location', 'type': 'France.', 'tail': 'Located In', 'tail_type': 'Location'
                },
                {'head': 'Guernsey', 'head_type': 'Location', 'type': 'France.', 'tail': 'Located In', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wharf Holdings', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Hong Kong', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jack MacAllister', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U S West inc.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Lawrence Kane Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Cincinnati', 'tail_type': 'Location'
                },
                {'head': 'Lawrence Kane Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Ohio', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Jeff Widener', 'head_type': 'Person', 'type': 'Work for', 'tail': 'AP', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Klong Toey', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Bangkok', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ofer Bar-Yosef', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Harvard University', 'tail_type': 'Organization'
                },
                {'head': 'Bernard Vandermeersch', 'head_type': 'Person', 'type': 'Work for', 'tail': 'University of Bordeaux', 'tail_type': 'Organization'
                },
                {'head': 'Bernard Vandermeersch', 'head_type': 'Person', 'type': 'Live in', 'tail': 'France', 'tail_type': 'Location'
                },
                {'head': 'University of Bordeaux', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'France', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Carlos Tenev', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Peronist Party', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Guernsey', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Britain', 'tail_type': 'Location'
                },
                {'head': 'Guernsey', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Channel Islands', 'tail_type': 'Location'
                },
                {'head': 'Channel Islands', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Britain', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Wharf Holdings', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Hong Kong', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jack MacAllister', 'head_type': 'Person', 'type': 'Work for', 'tail': 'U S West inc.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Lawrence Kane Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Cincinnati', 'tail_type': 'Location'
                },
                {'head': 'Lawrence Kane Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Ohio', 'tail_type': 'Location'
                },
                {'head': 'Cincinnati', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Ohio', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Jean-Luckenson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Signal FM.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'EZLN', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Mexico', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ITAR-TASS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ITAR-TASS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Stepanakert', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Azerbaijan.', 'tail_type': 'Location'
                },
                {'head': 'Stepanakert', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Nagorno-Karabakh', 'tail_type': 'Location'
                },
                {'head': 'Stepanakert', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Azerbaijan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Gianfranco Fini', 'head_type': 'Person', 'type': 'Work for', 'tail': 'National Alliance', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Namialo', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Nampula Province', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'NIHON KEIZAI SHIMBUN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Tokyo', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Jean-Luckenson', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Signal FM.', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Mexican Southeast.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Mexico', 'tail_type': 'Location'
                },
                {'head': 'EZLN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Mexican Southeast.', 'tail_type': 'Location'
                },
                {'head': 'EZLN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Mexico', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ITAR-TASS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ITAR-TASS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Stepanakert', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Nagorno-Karabakh', 'tail_type': 'Location'
                },
                {'head': 'Nagorno-Karabakh', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Azerbaijan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Gianfranco Fini', 'head_type': 'Person', 'type': 'Work for', 'tail': 'National Alliance', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Nampula Province', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Namialo', 'tail_type': 'Location'
                },
                {'head': 'Northern Improvement Brigade', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Namialo', 'tail_type': 'Location'
                },
                {'head': 'Northern Improvement Brigade', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nampula Province', 'tail_type': 'Location'
                },
                {'head': 'Northern Improvement Brigade', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nampula', 'tail_type': 'Location'
                },
                {'head': 'Brigada de Melhoramentos do Norte', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Namialo', 'tail_type': 'Location'
                },
                {'head': 'Brigada de Melhoramentos do Norte', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nampula Province', 'tail_type': 'Location'
                },
                {'head': 'Brigada de Melhoramentos do Norte', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nampula', 'tail_type': 'Location'
                },
                {'head': 'BMN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Namialo', 'tail_type': 'Location'
                },
                {'head': 'BMN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nampula Province', 'tail_type': 'Location'
                },
                {'head': 'BMN', 'head_type': 'Organization', 'type': 'Organization', 'tail': 'Nampula', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'NIHON KEIZAI SHIMBUN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Tokyo', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Branko Vojnic', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Beli Manastir', 'tail_type': 'Location'
                },
                {'head': 'Branko Vojnic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Krajina Serb Democratic Party', 'tail_type': 'Organization'
                },
                {'head': 'Branko Vojnic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'SDS', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Sofia BTA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sofia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Radio Rebelde Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Havana', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'AFP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Paris', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Radio Lebanon', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beirut', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ANP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'The Hague', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE JERUSALEM POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Jerusalem', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE JERUSALEM POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Jerusalem', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Branko Vojnic', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Beli Manastir', 'tail_type': 'Location'
                },
                {'head': 'Marko Atlagic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Serb Democratic Party', 'tail_type': 'Organization'
                },
                {'head': 'Marko Atlagic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'SDS', 'tail_type': 'Organization'
                },
                {'head': 'Milan Ernjakovic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Serb Democratic Party', 'tail_type': 'Organization'
                },
                {'head': 'Milan Ernjakovic', 'head_type': 'Person', 'type': 'Work for', 'tail': 'SDS', 'tail_type': 'Organization'
                },
                {'head': 'Krajina', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Serb Democratic Party', 'tail_type': 'Organization'
                },
                {'head': 'Krajina', 'head_type': 'Person', 'type': 'Work for', 'tail': 'SDS', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'BTA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sofia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Radio Rebelde Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Havana', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'AFP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Paris', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Radio Lebanon', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beirut', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ANP', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'The Hague', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE JERUSALEM POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Jerusalem', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE JERUSALEM POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Jerusalem', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Gerald Steinberg', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Bar-Ilan University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Steven Bryen', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pentagon', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Massachusetts Institute of Technology', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Boston', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Australian Embassies', 'head_type': 'Location', 'type': 'Organization based in', 'tail': 'Jakarta', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Australian Government', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Australia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Yongbyon.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'North Korea', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ricardo Cabrisas', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Cuba', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Miguel Rodriguez Mendoza', 'head_type': 'Person', 'type': 'Work for', 'tail': 'ICE', 'tail_type': 'Organization'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Gerald Steinberg', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Bar-Ilan University', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Steven Bryen', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pentagon', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Pedatzur', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Massachusetts Institute of Technology', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Australian Embassies', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Jakarta', 'tail_type': 'Location'
                },
                {'head': 'Australian Embassies', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Bangkok', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Australian Government', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Australia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Yongbyon.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'North Korea', 'tail_type': 'Location'
                },
                {'head': 'Yongbyon.', 'head_type': 'Location', 'type': 'Located In', 'tail': 'North Korea', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'John Savage', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Nova Scotia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Miguel Rodriguez Mendoza', 'head_type': 'Person', 'type': 'Work for', 'tail': 'ICE', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'S. Gusak', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Belarusian', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Duesseldorf HANDELSBLATT', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Duesseldorf', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jordi Aguil&oacute', 'head_type': 'Person', 'type': 'Work for', 'tail': 'CNM', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Santiago', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Chile', 'tail_type': 'Location'
                },
                {'head': 'Valparaiso', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Chile', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'O GLOBO', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Rio de Janeiro', 'tail_type': 'Location'
                }
            ],
            [
                {'head': "Sao Paulo State Attorney's Office", 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Federal Employees Union', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Federal Employees Union', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sindisef', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Teleonce Television', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Guatemala City', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'S. Gusak', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Belarusian', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'HANDELSBLATT', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Duesseldorf', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jordi Aguil&oacute', 'head_type': 'Person', 'type': 'Work for', 'tail': 'CNM', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'EFE', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Santiago', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'O GLOBO', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Rio de Janeiro', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Institute for Nuclear and Energy Research', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Institute for Nuclear and Energy Research', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Institute for Nuclear and Energy Research', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Ipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Association of Ipen Employees', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Assipen', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                },
                {'head': 'Federal Employees Union', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Sao Paulo', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Teleonce Television', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Guatemala City', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Stanislav Mikhaylovich Korochkin', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Magadan Basin Okhotrybvod', 'tail_type': 'Organization'
                },
                {'head': 'Stanislav Mikhaylovich Korochkin', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Okhotsk Sea Fishing Administration', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Suomen Yleisradio Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Helsinki', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'EL COMERCIO', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Lima', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'San Ignacio de Cajamarca', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Jaen', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'San Martin Department', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Amazonas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'PRAVDA UKRAINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ivan Plyushch', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Ukrainian', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'JINGJI YANJIU', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beijing', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Stanislav Mikhaylovich Korochkin', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Magadan Basin Okhotrybvod ( Okhotsk Sea Fishing Administration ) Department', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Suomen Yleisradio Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Helsinki', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'EL COMERCIO', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Lima', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'San Ignacio forest', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Jaen', 'tail_type': 'Location'
                },
                {'head': 'San Ignacio forest', 'head_type': 'Location', 'type': 'Located In', 'tail': 'San Ignacio de Cajamarca', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Huancabamba', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Piura', 'tail_type': 'Location'
                },
                {'head': 'Bagua', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Amazonas', 'tail_type': 'Location'
                },
                {'head': 'Condorcanqui', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Amazonas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'PRAVDA UKRAINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ivan Plyushch', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Ukrainian', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'JINGJI YANJIU', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beijing', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Deng Nan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'State Science and Technology Commission', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Deng Nan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'China', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                },
                {'head': 'Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Pom-myon', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Nonsan County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Il-song', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Korea', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'BANGKOK POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Bangkok', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'LA JORNADA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Mexico City', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ernesto Zedillo Ponce de Leon', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Valley of Mexico', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': "National People's Congress", 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Beijing', 'tail_type': 'Location'
                },
                {'head': "National People's Congress", 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'China', 'tail_type': 'Location'
                },
                {'head': 'State Science and Technology Commission', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'China', 'tail_type': 'Location'
                },
                {'head': 'Deng Nan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'China', 'tail_type': 'Location'
                },
                {'head': 'Deng Nan', 'head_type': 'Person', 'type': 'Work for', 'tail': 'State Science and Technology Commission', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Deng Nan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'China', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'United States', 'tail_type': 'Location'
                },
                {'head': 'Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'U.S.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Pom-myon', 'head_type': 'Person', 'type': 'Work for', 'tail': 'LDP', 'tail_type': 'Organization'
                },
                {'head': 'Kim Pom-myon', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Nonsan County', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Il-song', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Korea', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'BANGKOK POST', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Bangkok', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'LA JORNADA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Mexico City', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ernesto Zedillo Ponce de Leon', 'head_type': 'Person', 'type': 'Work for', 'tail': 'PRI', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'ENTV Television Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Algiers', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ENTV Television Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Algiers', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'NEZAVISIMAYA GAZETA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE HINDU', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Madras', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ACAN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Panama City', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'SAPA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Johannesesburg', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mr Nelson Rohihlahla Mandela', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Republic of South Africa', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'KNA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nairobi', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'ENTV Television Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Algiers', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ENTV Television Network', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Algiers', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'NEZAVISIMAYA GAZETA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Moscow', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'THE HINDU', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Madras', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'ACAN', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Panama City', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'SAPA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Johannesburg', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Mr Nelson Rohihlahla Mandela', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Republic of South Africa', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'KNA', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Nairobi', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Nelson Mandela', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Africa', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Hyong-ki', 'head_type': 'Person', 'type': 'Work for', 'tail': 'NUB', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Slovak Foreign Ministry', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Bratislava', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rene Steichen', 'head_type': 'Person', 'type': 'Work for', 'tail': 'EU', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': "Yasir 'Arafat", 'head_type': 'Person', 'type': 'Work for', 'tail': 'PLO', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Georgiy Gurinov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pacific Fleet', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Viktor Posuvalyuk', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Russian Foreign Ministry', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Sergey Rogov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Russian Center for Problems of National Security and International Relations', 'tail_type': 'Organization'
                }
            ]
        ], 'labels': [
            [
                {'head': 'African National Congress', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'South Africa', 'tail_type': 'Location'
                },
                {'head': 'ANC', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'South Africa', 'tail_type': 'Location'
                },
                {'head': 'Nelson Mandela', 'head_type': 'Person', 'type': 'Work for', 'tail': 'African National Congress', 'tail_type': 'Organization'
                },
                {'head': 'Nelson Mandela', 'head_type': 'Person', 'type': 'Work for', 'tail': 'ANC', 'tail_type': 'Organization'
                },
                {'head': 'Nelson Mandela', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Africa', 'tail_type': 'Location'
                },
                {'head': 'de Klerk', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Africa', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Kim Hyong-ki', 'head_type': 'Person', 'type': 'Work for', 'tail': 'NUB', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Gabcikovo derivation canal', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Slovakia', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'EU', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Brussels', 'tail_type': 'Location'
                }
            ],
            [
                {'head': "Yasir 'Arafat", 'head_type': 'Person', 'type': 'Work for', 'tail': 'PLO', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Georgiy Gurinov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Pacific Fleet', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Viktor Posuvalyuk', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Middle East and Africa department', 'tail_type': 'Organization'
                },
                {'head': 'Viktor Posuvalyuk', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Russian Foreign Ministry', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Sergey Rogov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Center for Problems of National Security and International Relations', 'tail_type': 'Organization'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'BASAPRESS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Chisinau', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Valentin Krylov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Socialist Party', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Federal Administrative Court', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Berlin', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Institute of Organic Chemistry', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Shanghai', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'HOLOS UKRAYINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'HOLOS UKRAYINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ukraine', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Soviet Union', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'BASAPRESS', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Chisinau', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Valentin Krylov', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Socialist Party', 'tail_type': 'Organization'
                }
            ],
            [
                {'head': 'Federal Administrative Court', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Berlin', 'tail_type': 'Location'
                },
                {'head': 'Federal Administrative Court', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Federal Republic', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Institute of Organic Chemistry', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Shanghai', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'HOLOS UKRAYINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'HOLOS UKRAYINY', 'head_type': 'Organization', 'type': 'Organization based in', 'tail': 'Kiev', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ukraine', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Soviet Union', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Bishara Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Dr. Martin Luther King Jr', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Bishara Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Dr. Martin Luther King Jr', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Charles J. Guiteau', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President James Garfield', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lee Harvey Oswald', 'tail_type': 'Person'
                },
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lee Harvey Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Martini', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Irving Flax', 'tail_type': 'Person'
                },
                {'head': 'Therese Afdahl', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Irving Flax', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvard Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'New York Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Charles J. Guiteau', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President James Garfield', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Martini', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Irving Flax', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvard Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'New York Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Sirhan Bishara Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Abraham Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Charlotte Corday', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Jean Paul Marat', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Dr. Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'King', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Sirhan Bishara Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Abraham Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Charlotte Corday', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Jean Paul Marat', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Dr. Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'King', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King Jr.', 'tail_type': 'Person'
                },
                {'head': 'Memphis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Tenn.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lee Harvey Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'John F. Kennedy', 'tail_type': 'Person'
                },
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lee Harvey Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Kim Jae-kyu', 'head_type': 'Person', 'type': 'Kill', 'tail': 'South Korean President Park Chung-hee', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'John Lennon', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Kennedy.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lee Harvey Oswald', 'tail_type': 'Person'
                },
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'John F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Kim Jae-kyu', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Park Chung-hee', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'John Lennon', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Kleber Elias Gia Bustamante', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Jose Antonio Briz Lopez.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Rigoberto Lopez Perez', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Somoza Garcia', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                },
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Mark David Chapman', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Lennon', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Kleber Elias Gia Bustamante', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Jose Antonio Briz Lopez.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Martin Luther King', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Rigoberto Lopez Perez', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Somoza Garcia', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan B. Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Sirhan Sirhan', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Sen. Robert F. Kennedy', 'tail_type': 'Person'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Rev. Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Abraham Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Elizabeth', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Elizabeth Dole', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Salisbury, N.C.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'COLUMBIA', 'head_type': 'Location', 'type': 'Located In', 'tail': 'S.C.', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Jack Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Lee Harvey Oswald', 'head_type': 'Person', 'type': 'Kill', 'tail': 'President Kennedy', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'James Earl Ray', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Rev. Martin Luther King Jr.', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Ruby', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Oswald', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'John Wilkes Booth', 'head_type': 'Person', 'type': 'Kill', 'tail': 'Abraham Lincoln', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Elizabeth', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Elizabeth Dole', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Salisbury, N.C.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lowell Thomas', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Woodington, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eric Sevareid', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Velva', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Charles Lindbergh', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Wallace, S.D.', 'tail_type': 'Location'
                },
                {'head': 'Charles Lindbergh', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Englewood, N.J.', 'tail_type': 'Location'
                },
                {'head': 'Anne Spencer Morrow', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Englewood, N.J.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Brigham Young', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Whitingham, Vt', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Will Rogers', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Oklahoma', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Owens', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Danville, Ala.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Springsteen', 'head_type': 'Person', 'type': 'Live in', 'tail': 'New Jersey', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lowell Thomas', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Woodington, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Eric Sevareid', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Velva', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Hubert H. Humphrey', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Wallace, S.D.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Brigham Young', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Whitingham, Vt', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Will Rogers', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Oklahoma', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Owens', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Danville, Ala.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Springsteen', 'head_type': 'Person', 'type': 'Live in', 'tail': 'New Jersey', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'James Garfield', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Orange, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Atwater', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                },
                {'head': 'Atwater', 'head_type': 'Person', 'type': 'Work for', 'tail': 'Sen. Strom Thurmond', 'tail_type': 'Person'
                }
            ],
            [
                {'head': 'Barbara Hutson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'New Orleans', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Texas Tech University', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Lubbock', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'John Deere', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Rutland, Vt.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ulysses S. Grant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Point Pleasant, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'James Monroe', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Westmoreland County,Virginia', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'James Garfield', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Orange, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Atwater', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Fats Domino', 'head_type': 'Person', 'type': 'Live in', 'tail': 'New Orleans', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Holly', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lubbock', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'John Deere', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Rutland, Vt.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rev. Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Ulysses S. Grant', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Point Pleasant, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'James Monroe', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Westmoreland County,Virginia', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Bob Dole', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Russell, Kan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Dwight D. Eisenhower', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Denison, Texas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Martin Van Buren', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Kinderhook, N.Y.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Elvis Presley', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Tupelo, Miss', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bob Dylan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Duluth', 'tail_type': 'Location'
                },
                {'head': 'Bob Dylan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Hibbing', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Andrew Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Waxhaw, S.C.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Benjamin Harrison', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Bend, Ohio', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Sen. Bob Dole', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Russell, Kan.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rev. Jesse Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Carolina', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Dwight D. Eisenhower', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Denison, Texas', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Martin Van Buren', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Kinderhook, N.Y.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Elvis Presley', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Tupelo, Miss', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bob Dylan', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Duluth', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Andrew Jackson', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Waxhaw, S.C.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Benjamin Harrison', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Bend, Ohio', 'tail_type': 'Location'
                }
            ]
        ]
    },
    {'predictions': [
            [
                {'head': 'Oliver Hazard Perry', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Kingstown, R.I.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rutherford B. Hayes', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Delaware, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'James Garfield', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Orange, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Dwight D. Eisenhower', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Denison, Tex', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bet Davis', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lowell, Mass', 'tail_type': 'Location'
                },
                {'head': 'Ruth Elizabeth Davis', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lowell, Mass', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Alexander Helms Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Monroe, population 3,000', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lawrence Welk', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Dakota', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Indianapolis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Indiana', 'tail_type': 'Location'
                }
            ]
        ], 'labels': [
            [
                {'head': 'Oliver Hazard Perry', 'head_type': 'Person', 'type': 'Live in', 'tail': 'South Kingstown, R.I.', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Rutherford B. Hayes', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Delaware, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'James Garfield', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Orange, Ohio', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Dwight D. Eisenhower', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Denison, Tex', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Bette Davis', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lowell, Mass', 'tail_type': 'Location'
                },
                {'head': 'Ruth Elizabeth Davis', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Lowell, Mass', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Jesse Alexander Helms Jr.', 'head_type': 'Person', 'type': 'Live in', 'tail': 'Monroe', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Lawrence Welk', 'head_type': 'Person', 'type': 'Live in', 'tail': 'North Dakota', 'tail_type': 'Location'
                }
            ],
            [
                {'head': 'Indianapolis', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Indiana', 'tail_type': 'Location'
                }
            ]
        ]
    }
]"""

# %%
predictions_ground_truth_filepath = "/work3/s174159/LLM_Thesis/SOTA/REBEL/src/predictions.json"

# %%
pd_gt = eval(output)

# %%
inc = 0

import json

lines = []

for tj,batched_predictions_labels in enumerate(pd_gt[1:]):
    sent_predictions = batched_predictions_labels['predictions']
    sent_labels = batched_predictions_labels['labels']
    for t,(predictions,labels) in enumerate(zip(sent_predictions,sent_labels)):
        wrong_predictions = predictions.copy()
        for pred in predictions:
            for label in labels:
                if pred == labels:
                    wrong_predictions.remove(pred)
                    break
        if len(wrong_predictions) > 0:
            lines.append({"testFileRow":inc,"predictions":wrong_predictions,"labels":labels})
        inc +=1
    
with open('/work3/s174159/LLM_Thesis/SOTA/REBEL/src/outputs/2024-09-11/outfile.json','w') as f:
    f.write(json.dumps(lines))
    f.write("\n")

# %%
p = [[{'head': 'Hakawati Theatre', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Arab east Jerusalem', 'tail_type': 'Location'}]]
l = [[{'head': 'Hakawati Theatre', 'head_type': 'Location', 'type': 'Located In', 'tail': 'Arab east Jerusalem', 'tail_type': 'Location'}]]

p == l
# Out:
# True
